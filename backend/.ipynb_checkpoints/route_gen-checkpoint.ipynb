# %%
# %pip install copernicusmarine
# %pip install scikit-image
# Out:
# Requirement already satisfied: copernicusmarine in c:\users\home account\appdata\local\programs\python\python310\lib\site-packages (1.3.3)
# Requirement already satisfied: aiohttp<3.10.0,>=3.9.4 in c:\users\home account\appdata\local\programs\python\python310\lib\site-packages (from copernicusmarine) (3.9.5)
# Requirement already satisfied: boto3>=1.25 in c:\users\home account\appdata\local\programs\python\python310\lib\site-packages (from copernicusmarine) (1.35.12)
# Requirement already satisfied: cachier>=2.2.1 in c:\users\home account\appdata\local\programs\python\python310\lib\site-packages (from copernicusmarine) (3.0.1)
# Requirement already satisfied: click>=8.0.4 in c:\users\home account\appdata\local\programs\python\python310\lib\site-packages (from copernicusmarine) (8.1.7)
# Requirement already satisfied: dask>=2022 in c:\users\home account\appdata\local\programs\python\python310\lib\site-packages (from copernicusmarine) (2024.8.2)
# Requirement already satisfied: lxml>=4.9.0 in c:\users\home account\appdata\local\programs\python\python310\lib\site-packages (from copernicusmarine) (5.3.0)
# Requirement already satisfied: nest-asyncio>=1.5.8 in c:\users\home account\appdata\local\programs\python\python310\lib\site-packages (from copernicusmarine) (1.6.0)
# Requirement already satisfied: netCDF4>=1.5.4 in c:\users\home account\appdata\local\programs\python\python310\lib\site-packages (from copernicusmarine) (1.7.1.post2)
# Requirement already satisfied: numpy<2.0.0,>=1.23.0 in c:\users\home account\appdata\local\programs\python\python310\lib\site-packages (from copernicusmarine) (1.26.0)
# Requirement already satisfied: pystac>=1.8.3 in c:\users\home account\appdata\local\programs\python\python310\lib\site-packages (from copernicusmarine) (1.10.1)
# Requirement already satisfied: requests>=2.27.1 in c:\users\home account\appdata\local\programs\python\python310\lib\site-packages (from copernicusmarine) (2.31.0)
# Requirement already satisfied: semver>=3.0.2 in c:\users\home account\appdata\local\programs\python\python310\lib\site-packages (from copernicusmarine) (3.0.2)
# Requirement already satisfied: setuptools>=68.2.2 in c:\users\home account\appdata\local\programs\python\python310\lib\site-packages (from copernicusmarine) (74.1.1)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\home account\appdata\local\programs\python\python310\lib\site-packages (from copernicusmarine) (4.66.5)
# Requirement already satisfied: xarray>=2023.4.0 in c:\users\home account\appdata\local\programs\python\python310\lib\site-packages (from copernicusmarine) (2024.7.0)
# Requirement already satisfied: zarr>=2.13.3 in c:\users\home account\appdata\local\programs\python\python310\lib\site-packages (from copernicusmarine) (2.18.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\home account\appdata\local\programs\python\python310\lib\site-packages (from aiohttp<3.10.0,>=3.9.4->copernicusmarine) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\home account\appdata\local\programs\python\python310\lib\site-packages (from aiohttp<3.10.0,>=3.9.4->copernicusmarine) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\home account\appdata\local\programs\python\python310\lib\site-packages (from aiohttp<3.10.0,>=3.9.4->copernicusmarine) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\home account\appdata\local\programs\python\python310\lib\site-packages (from aiohttp<3.10.0,>=3.9.4->copernicusmarine) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\home account\appdata\local\programs\python\python310\lib\site-packages (from aiohttp<3.10.0,>=3.9.4->copernicusmarine) (1.9.10)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in c:\users\home account\appdata\local\programs\python\python310\lib\site-packages (from aiohttp<3.10.0,>=3.9.4->copernicusmarine) (4.0.3)
# Requirement already satisfied: botocore<1.36.0,>=1.35.12 in c:\users\home account\appdata\local\programs\python\python310\lib\site-packages (from boto3>=1.25->copernicusmarine) (1.35.12)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\home account\appdata\local\programs\python\python310\lib\site-packages (from boto3>=1.25->copernicusmarine) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in c:\users\home account\appdata\local\programs\python\python310\lib\site-packages (from boto3>=1.25->copernicusmarine) (0.10.2)
# Requirement already satisfied: portalocker>=2.3.2 in c:\users\home account\appdata\local\programs\python\python310\lib\site-packages (from cachier>=2.2.1->copernicusmarine) (2.10.1)
# Requirement already satisfied: watchdog>=2.3.1 in c:\users\home account\appdata\local\programs\python\python310\lib\site-packages (from cachier>=2.2.1->copernicusmarine) (5.0.2)
# Requirement already satisfied: colorama in c:\users\home account\appdata\local\programs\python\python310\lib\site-packages (from click>=8.0.4->copernicusmarine) (0.4.6)
# Requirement already satisfied: cloudpickle>=3.0.0 in c:\users\home account\appdata\local\programs\python\python310\lib\site-packages (from dask>=2022->copernicusmarine) (3.0.0)
# Requirement already satisfied: fsspec>=2021.09.0 in c:\users\home account\appdata\local\programs\python\python310\lib\site-packages (from dask>=2022->copernicusmarine) (2024.9.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\home account\appdata\local\programs\python\python310\lib\site-packages (from dask>=2022->copernicusmarine) (24.0)
# Requirement already satisfied: partd>=1.4.0 in c:\users\home account\appdata\local\programs\python\python310\lib\site-packages (from dask>=2022->copernicusmarine) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\home account\appdata\local\programs\python\python310\lib\site-packages (from dask>=2022->copernicusmarine) (6.0.1)
# Requirement already satisfied: toolz>=0.10.0 in c:\users\home account\appdata\local\programs\python\python310\lib\site-packages (from dask>=2022->copernicusmarine) (0.12.1)
# Requirement already satisfied: importlib-metadata>=4.13.0 in c:\users\home account\appdata\local\programs\python\python310\lib\site-packages (from dask>=2022->copernicusmarine) (8.4.0)
# Requirement already satisfied: cftime in c:\users\home account\appdata\local\programs\python\python310\lib\site-packages (from netCDF4>=1.5.4->copernicusmarine) (1.6.4)
# Requirement already satisfied: certifi in c:\users\home account\appdata\local\programs\python\python310\lib\site-packages (from netCDF4>=1.5.4->copernicusmarine) (2023.7.22)
# Requirement already satisfied: python-dateutil>=2.7.0 in c:\users\home account\appdata\local\programs\python\python310\lib\site-packages (from pystac>=1.8.3->copernicusmarine) (2.9.0.post0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\home account\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.27.1->copernicusmarine) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\home account\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.27.1->copernicusmarine) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\home account\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.27.1->copernicusmarine) (2.2.1)
# Requirement already satisfied: pandas>=2.0 in c:\users\home account\appdata\local\programs\python\python310\lib\site-packages (from xarray>=2023.4.0->copernicusmarine) (2.2.1)
# Requirement already satisfied: asciitree in c:\users\home account\appdata\local\programs\python\python310\lib\site-packages (from zarr>=2.13.3->copernicusmarine) (0.3.3)
# Requirement already satisfied: numcodecs>=0.10.0 in c:\users\home account\appdata\local\programs\python\python310\lib\site-packages (from zarr>=2.13.3->copernicusmarine) (0.13.0)
# Requirement already satisfied: fasteners in c:\users\home account\appdata\local\programs\python\python310\lib\site-packages (from zarr>=2.13.3->copernicusmarine) (0.19)
# Requirement already satisfied: zipp>=0.5 in c:\users\home account\appdata\local\programs\python\python310\lib\site-packages (from importlib-metadata>=4.13.0->dask>=2022->copernicusmarine) (3.20.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\home account\appdata\local\programs\python\python310\lib\site-packages (from pandas>=2.0->xarray>=2023.4.0->copernicusmarine) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\home account\appdata\local\programs\python\python310\lib\site-packages (from pandas>=2.0->xarray>=2023.4.0->copernicusmarine) (2024.1)
# Requirement already satisfied: locket in c:\users\home account\appdata\local\programs\python\python310\lib\site-packages (from partd>=1.4.0->dask>=2022->copernicusmarine) (1.0.0)
# Requirement already satisfied: pywin32>=226 in c:\users\home account\appdata\local\programs\python\python310\lib\site-packages (from portalocker>=2.3.2->cachier>=2.2.1->copernicusmarine) (306)
# Requirement already satisfied: six>=1.5 in c:\users\home account\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7.0->pystac>=1.8.3->copernicusmarine) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: scikit-image in c:\users\home account\appdata\local\programs\python\python310\lib\site-packages (0.24.0)
# Requirement already satisfied: numpy>=1.23 in c:\users\home account\appdata\local\programs\python\python310\lib\site-packages (from scikit-image) (1.26.0)
# Requirement already satisfied: scipy>=1.9 in c:\users\home account\appdata\local\programs\python\python310\lib\site-packages (from scikit-image) (1.13.0)
# Requirement already satisfied: networkx>=2.8 in c:\users\home account\appdata\local\programs\python\python310\lib\site-packages (from scikit-image) (3.1)
# Requirement already satisfied: pillow>=9.1 in c:\users\home account\appdata\local\programs\python\python310\lib\site-packages (from scikit-image) (10.3.0)
# Requirement already satisfied: imageio>=2.33 in c:\users\home account\appdata\local\programs\python\python310\lib\site-packages (from scikit-image) (2.35.1)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\home account\appdata\local\programs\python\python310\lib\site-packages (from scikit-image) (2024.8.30)
# Requirement already satisfied: packaging>=21 in c:\users\home account\appdata\local\programs\python\python310\lib\site-packages (from scikit-image) (24.0)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\home account\appdata\local\programs\python\python310\lib\site-packages (from scikit-image) (0.4)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import copernicusmarine
import pandas as pd
import numpy as np
import xarray as xr
from skimage.graph import route_through_array
from matplotlib import pyplot as plt

# %%
features = {
    'VHM0': 'Spectral significant wave height',
    'VTM10': 'Spectral moments (-1,0) wave period',
    'VTM02': 'Spectral moments (0,2) wave period',
    'VTPK': 'Wave period at spectral peak',
    'VMDR': 'Mean wave direction',
    'VPED': 'Wave principal direction at spectral peak',
    'VSDX': 'Stokes drift U',
    'VSDY': 'Stokes drift V',
    'VHM0_WW': 'Spectral significant wind wave height',
    'VTM01_WW': 'Spectral moments (0,1) wind wave period',
    'VMDR_WW': 'Mean wind wave direction',
    'VHM0_SW1': 'Spectral significant primary swell wave height',
    'VTM01_SW1': 'Spectral moments (0,1) primary swell wave period',
    'VMDR_SW1': 'Mean primary swell wave direction',
    'VHM0_SW2': 'Spectral significant secondary swell wave height',
    'VTM01_SW2': 'Spectral moments (0,1) secondary swell wave period',
    'VMDR_SW2': 'Mean secondary swell wave direction'
}

# %%
dataset = copernicusmarine.open_dataset(
  dataset_id="cmems_mod_glo_wav_anfc_0.083deg_PT3H-i",
  variables = [x for x in features],
  minimum_longitude=-180,
  maximum_longitude=179.91666666666666,
  minimum_latitude=-80,
  maximum_latitude=90,
  start_datetime="2024-09-05T00:00:00",
  end_datetime="2024-09-05T00:00:00",
)
# Out:
# INFO - 2024-09-06T01:48:51Z - Dataset version was not specified, the latest one was selected: "202311"
# INFO - 2024-09-06T01:48:51Z - Dataset part was not specified, the first one was selected: "default"
# INFO - 2024-09-06T01:49:01Z - Service was not specified, the default one was selected: "arco-geo-series"
# username:password:

# %%
dataset
# Out:
# <xarray.Dataset> Size: 1GB
# Dimensions:    (time: 1, latitude: 2041, longitude: 4320)
# Coordinates:
#   * latitude   (latitude) float64 16kB -80.0 -79.92 -79.83 ... 89.83 89.92 90.0
#   * longitude  (longitude) float64 35kB -180.0 -179.9 -179.8 ... 179.8 179.9
#   * time       (time) datetime64[ns] 8B 2024-09-05
# Data variables: (12/17)
#     VHM0       (time, latitude, longitude) float64 71MB ...
#     VTM10      (time, latitude, longitude) float64 71MB ...
#     VTM02      (time, latitude, longitude) float64 71MB ...
#     VTPK       (time, latitude, longitude) float64 71MB ...
#     VMDR       (time, latitude, longitude) float64 71MB ...
#     VPED       (time, latitude, longitude) float64 71MB ...
#     ...         ...
#     VHM0_SW1   (time, latitude, longitude) float64 71MB ...
#     VTM01_SW1  (time, latitude, longitude) float64 71MB ...
#     VMDR_SW1   (time, latitude, longitude) float64 71MB ...
#     VHM0_SW2   (time, latitude, longitude) float64 71MB ...
#     VTM01_SW2  (time, latitude, longitude) float64 71MB ...
#     VMDR_SW2   (time, latitude, longitude) float64 71MB ...
# Attributes: (12/16)
#     Conventions:           CF-1.6
#     area:                  GLO
#     contact:               servicedesk.cmems@mercator-ocean.eu
#     credit:                E.U. Copernicus Marine Service Information (CMEMS)
#     geospatial_lat_max:    90.0
#     geospatial_lat_min:    -80.0
#     ...                    ...
#     geospatial_lon_step:   0.0833282470703125
#     geospatial_lon_units:  degree
#     institution:           METEO-FRANCE
#     producer:              CMEMS - Global Monitoring and Forecasting Centre
#     product:               GLOBAL_ANALYSIS_FORECAST_WAV_001_027
#     references:            http://marine.copernicus.eu

# %%
cmap_dict = {
    'VHM0': 'viridis',
    'VTM10': 'cividis',
    'VTM02': 'cividis',
    'VTPK': 'magma',
    'VMDR': 'ocean',
    'VPED': 'ocean',
    'VSDX': 'cividis',
    'VSDY': 'cividis',
    'VHM0_WW': 'viridis',
    'VTM01_WW': 'cividis',
    'VMDR_WW': 'ocean',
    'VHM0_SW1': 'viridis',
    'VTM01_SW1': 'cividis',
    'VMDR_SW1': 'ocean',
    'VHM0_SW2': 'viridis',
    'VTM01_SW2': 'cividis',
    'VMDR_SW2': 'ocean'
}


for feature in features:
    if hasattr(dataset, feature):
        cmap = cmap_dict.get(feature, 'viridis')  # Default to 'viridis' if not found
        dataset[feature].isel(time=0).plot(robust=True, aspect=2, size=7, cmap=cmap)
        plt.title(feature)
        plt.show()
    else:
        print(f"Feature {feature} not found in dataset.")

# %%
df = dataset.to_dataframe()

# %%
df
# Out:
#                                  VHM0  VTM10  VTM02  VTPK  VMDR  VPED  VSDX  \
# time       latitude longitude
# 2024-09-05 -80.0    -180.000000   NaN    NaN    NaN   NaN   NaN   NaN   NaN
#                     -179.916667   NaN    NaN    NaN   NaN   NaN   NaN   NaN
#                     -179.833333   NaN    NaN    NaN   NaN   NaN   NaN   NaN
#                     -179.750000   NaN    NaN    NaN   NaN   NaN   NaN   NaN
#                     -179.666667   NaN    NaN    NaN   NaN   NaN   NaN   NaN
# ...                               ...    ...    ...   ...   ...   ...   ...
#             90.0     179.583333   NaN    NaN    NaN   NaN   NaN   NaN   NaN
#                      179.666667   NaN    NaN    NaN   NaN   NaN   NaN   NaN
#                      179.750000   NaN    NaN    NaN   NaN   NaN   NaN   NaN
#                      179.833333   NaN    NaN    NaN   NaN   NaN   NaN   NaN
#                      179.916667   NaN    NaN    NaN   NaN   NaN   NaN   NaN
#
#                                  VSDY  VHM0_WW  VTM01_WW  VMDR_WW  VHM0_SW1  \
# time       latitude longitude
# 2024-09-05 -80.0    -180.000000   NaN      NaN       NaN      NaN       NaN
#                     -179.916667   NaN      NaN       NaN      NaN       NaN
#                     -179.833333   NaN      NaN       NaN      NaN       NaN
#                     -179.750000   NaN      NaN       NaN      NaN       NaN
#                     -179.666667   NaN      NaN       NaN      NaN       NaN
# ...                               ...      ...       ...      ...       ...
#             90.0     179.583333   NaN      NaN       NaN      NaN       NaN
#                      179.666667   NaN      NaN       NaN      NaN       NaN
#                      179.750000   NaN      NaN       NaN      NaN       NaN
#                      179.833333   NaN      NaN       NaN      NaN       NaN
#                      179.916667   NaN      NaN       NaN      NaN       NaN
#
#                                  VTM01_SW1  VMDR_SW1  VHM0_SW2  VTM01_SW2  \
# time       latitude longitude
# 2024-09-05 -80.0    -180.000000        NaN       NaN       NaN        NaN
#                     -179.916667        NaN       NaN       NaN        NaN
#                     -179.833333        NaN       NaN       NaN        NaN
#                     -179.750000        NaN       NaN       NaN        NaN
#                     -179.666667        NaN       NaN       NaN        NaN
# ...                                    ...       ...       ...        ...
#             90.0     179.583333        NaN       NaN       NaN        NaN
#                      179.666667        NaN       NaN       NaN        NaN
#                      179.750000        NaN       NaN       NaN        NaN
#                      179.833333        NaN       NaN       NaN        NaN
#                      179.916667        NaN       NaN       NaN        NaN
#
#                                  VMDR_SW2
# time       latitude longitude
# 2024-09-05 -80.0    -180.000000       NaN
#                     -179.916667       NaN
#                     -179.833333       NaN
#                     -179.750000       NaN
#                     -179.666667       NaN
# ...                                   ...
#             90.0     179.583333       NaN
#                      179.666667       NaN
#                      179.750000       NaN
#                      179.833333       NaN
#                      179.916667       NaN
#
# [8817120 rows x 17 columns]

# %%
lat_NY = 40.7128
lon_NY = -74.0060
lat_LS = 38.7223
lon_LS = -9.1393

# %%
# Get array index to the value that is closest to a given value
def get_closest(array, value):
    return np.abs(array - value).argmin()

# %%
start_lon = get_closest(dataset.longitude.data, lon_NY)
start_lat = get_closest(dataset.latitude.data, lat_NY)
end_lon = get_closest(dataset.longitude.data,lon_LS)
end_lat = get_closest(dataset.latitude.data,lat_LS)

# %%
start = (start_lat, start_lon)
end = (end_lat, end_lon)

# %%
feature_costs = {}
feature_nans = {}

for feature in features:
    if hasattr(dataset, feature):
        # Store the cost data for each feature in the dictionary
        costs = dataset[feature].data[0]
        feature_costs[f"{feature}_costs"] = costs
        
        # Check where NaN values are present in the cost data and store in feature_nans
        whereAreNans = np.isnan(costs)
        feature_nans[f"{feature}_nans"] = whereAreNans

    else:
        print(f"Feature {feature} not found in dataset.")

# %%
feature_costs
# Out:
# {'VHM0_costs': array([[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]]),
#  'VTM10_costs': array([[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]]),
#  'VTM02_costs': array([[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]]),
#  'VTPK_costs': array([[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]]),
#  'VMDR_costs': array([[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]]),
#  'VPED_costs': array([[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]]),
#  'VSDX_costs': array([[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]]),
#  'VSDY_costs': array([[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]]),
#  'VHM0_WW_costs': array([[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]]),
#  'VTM01_WW_costs': array([[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]]),
#  'VMDR_WW_costs': array([[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]]),
#  'VHM0_SW1_costs': array([[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]]),
#  'VTM01_SW1_costs': array([[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]]),
#  'VMDR_SW1_costs': array([[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]]),
#  'VHM0_SW2_costs': array([[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]]),
#  'VTM01_SW2_costs': array([[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]]),
#  'VMDR_SW2_costs': array([[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]])}

# %%
feature_nans
# Out:
# {'VHM0_nans': array([[ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         ...,
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True]]),
#  'VTM10_nans': array([[ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         ...,
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True]]),
#  'VTM02_nans': array([[ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         ...,
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True]]),
#  'VTPK_nans': array([[ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         ...,
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True]]),
#  'VMDR_nans': array([[ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         ...,
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True]]),
#  'VPED_nans': array([[ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         ...,
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True]]),
#  'VSDX_nans': array([[ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         ...,
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True]]),
#  'VSDY_nans': array([[ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         ...,
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True]]),
#  'VHM0_WW_nans': array([[ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         ...,
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True]]),
#  'VTM01_WW_nans': array([[ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         ...,
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True]]),
#  'VMDR_WW_nans': array([[ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         ...,
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True]]),
#  'VHM0_SW1_nans': array([[ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         ...,
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True]]),
#  'VTM01_SW1_nans': array([[ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         ...,
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True]]),
#  'VMDR_SW1_nans': array([[ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         ...,
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True]]),
#  'VHM0_SW2_nans': array([[ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         ...,
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True]]),
#  'VTM01_SW2_nans': array([[ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         ...,
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True]]),
#  'VMDR_SW2_nans': array([[ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         ...,
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True]])}

# %%
for feature in features:
    if hasattr(dataset, feature):
        
        # Retrieve the stored cost data and NaN positions
        costs = feature_costs[f"{feature}_costs"]
        whereAreNans = feature_nans[f"{feature}_nans"]
        
        # Update the cost data where NaNs were found
        costs[whereAreNans] = 10**9
        
        # Store the updated costs back into feature_costs
        feature_costs[f"{feature}_costs"] = costs
    else:
        print(f"Feature {feature} not found in dataset.")

# %%
feature_costs
# Out:
# {'VHM0_costs': array([[1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         ...,
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09]]),
#  'VTM10_costs': array([[1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         ...,
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09]]),
#  'VTM02_costs': array([[1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         ...,
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09]]),
#  'VTPK_costs': array([[1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         ...,
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09]]),
#  'VMDR_costs': array([[1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         ...,
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09]]),
#  'VPED_costs': array([[1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         ...,
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09]]),
#  'VSDX_costs': array([[1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         ...,
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09]]),
#  'VSDY_costs': array([[1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         ...,
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09]]),
#  'VHM0_WW_costs': array([[1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         ...,
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09]]),
#  'VTM01_WW_costs': array([[1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         ...,
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09]]),
#  'VMDR_WW_costs': array([[1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         ...,
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09]]),
#  'VHM0_SW1_costs': array([[1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         ...,
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09]]),
#  'VTM01_SW1_costs': array([[1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         ...,
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09]]),
#  'VMDR_SW1_costs': array([[1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         ...,
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09]]),
#  'VHM0_SW2_costs': array([[1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         ...,
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09]]),
#  'VTM01_SW2_costs': array([[1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         ...,
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09]]),
#  'VMDR_SW2_costs': array([[1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         ...,
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09],
#         [1.e+09, 1.e+09, 1.e+09, ..., 1.e+09, 1.e+09, 1.e+09]])}

# %%
feature_weights = {
    'VHM0': 5,
    'VTM10': 4,
    'VTM02': 3,
    'VTPK': 4,
    'VMDR': 4,
    'VPED': 3,
    'VSDX': 2,
    'VSDY': 2,
    'VHM0_WW': 5,
    'VTM01_WW': 3,
    'VMDR_WW': 3,
    'VHM0_SW1': 4,
    'VTM01_SW1': 3,
    'VMDR_SW1': 3,
    'VHM0_SW2': 2,
    'VTM01_SW2': 2,
    'VMDR_SW2': 2
}

# %%
# Calculate the final cost array
final_cost = np.zeros_like(next(iter(feature_costs.values())))  # Initialize with the shape of any feature data
for feature in features:
    final_cost += feature_costs[f'{feature}_costs'] * feature_weights[feature]

# %%
plt.imshow(final_cost, cmap="hot", interpolation="nearest")
plt.gca().invert_yaxis();

# %%
def pathfinding(start, end):
    return route_through_array(final_cost, start, end, fully_connected=True)

# %%
indices, weight = pathfinding(start, end)
indices = np.stack(indices, axis=-1)

# %%
indices
# Out:
# array([[1449, 1448, 1447, ..., 1424, 1424, 1425],
#        [1272, 1272, 1272, ..., 2048, 2049, 2050]])

# %%
weight
# Out:
# 119185100363.73367

# %%
# Plot optimal route

plt.imshow(final_cost, aspect='auto', vmin=np.min(final_cost), vmax=0.5*np.max(final_cost));
# Route
plt.plot(indices[1],indices[0], 'r')
# Start/end points
plt.plot(start_lon, start_lat, 'k^', markersize=15)
plt.plot(end_lon, end_lat, 'k*', markersize=15)
plt.gca().invert_yaxis();
